# %%
from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
import numpy as np
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Activation
from keras.layers import Dropout
import pandas as pd
from datetime import datetime

# %%
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 1000)

# %%
# 读取并整理表格数据 输出为csv文件
df = pd.read_excel('./data/城市燃气小时负荷统计2021年.xls', index_col=None, header=None)
new_df = df[3:].iloc[:719, :25].reset_index(drop=True)
cols = ['date', '09:00:00', '10:00:00', '11:00:00', '12:00:00', '13:00:00', '14:00:00',
        '15:00:00', '16:00:00', '17:00:00', '18:00:00', '19:00:00', '20:00:00', '21:00:00',
        '22:00:00', '23:00:00', '00:00:00', '01:00:00', '02:00:00', '03:00:00', '04:00:00',
        '05:00:00', '06:00:00', '07:00:00', '08:00:00']
new_dataset = []
for i in range(719):
    for j in range(24):
        if j < 15:
            new_dataset.append([new_df[0][i].strftime("%m/%d/%Y") + ' ' + cols[j + 1], new_df[j + 1][i]])
        elif i == 718:
            new_dataset.append(['01/11/2021 ' + cols[j + 1], new_df[j + 1][i]])
        else:
            new_dataset.append([new_df[0][i + 1].strftime("%m/%d/%Y") + ' ' + cols[j + 1], new_df[j + 1][i]])
df = DataFrame(new_dataset, columns=['time', 'amount'])
df.to_csv('./data/城市燃气小时负荷统计.csv', index=False)

# %%
# 读取时间数据的格式化
def parser(x):
    return datetime.strptime(x, '%m/%d/%Y %H:%M:%S')

series = read_csv('data/城市燃气小时负荷统计.csv', header=0, parse_dates=[0], index_col=None, squeeze=True, 
                  date_parser=parser)
series = series.dropna()
series = series.reset_index(drop=True)

# %%
# 画折线图
series.plot('time', 'amount', title='2019-2021 Wuxi Gas Usage', figsize=(10,10));

# %%
# 画柱状图
plt.figure(figsize=(10, 10))
plt.bar(series['time'], series['amount'])
plt.title('2019-2021 Wuxi Gas Usage Barplot')
plt.xlabel('Date')
plt.ylabel('Gas Usage')
plt.show()

# %%
# 转换成差分数据
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# 逆差分
def inverse_difference(history, yhat):  # 历史数据，预测数据，差分间隔
    arr = [history[0]]
    for i in range(len(yhat)):
        arr.append(history[i] + yhat[i])
    return np.array(arr)

# %%
# 转换成监督数据，四列数据，3->1，三组预测一组
def series_to_supervised(data, n_in=1, n_out=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    # 将3组输入数据依次向下移动3，2，1行，将数据加入cols列表（技巧：(n_in, 0, -1)中的-1指倒序循环，步长为1）
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    # 将一组输出数据加入cols列表（技巧：其中i=0）
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # cols列表(list)中现在有四块经过下移后的数据(即：df(-3),df(-2),df(-1),df)，将四块数据按列 并排合并
    agg = concat(cols, axis=1)
    # 给合并后的数据添加列名
    agg.columns = names
    print(agg)
    return agg

# %%
raw_value = series['amount'].values
value = raw_value.astype('float32')
# value = difference(raw_value, 1) # 转换成差分数据
# 标准化/放缩 特征值在（0,1）之间
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(value.reshape(-1, 1))

# %%
# 用3小时数据预测一小时数据，1个特征值
n_hours = 7
n_features = 1
# 构造一个3->1的监督学习型数据
reframed = series_to_supervised(scaled, n_hours, 1)
print(reframed.shape)
reframed.dropna(inplace=True)
# Out:
#        var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 0            NaN        NaN        NaN        NaN        NaN        NaN
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN        NaN   0.443310
# 3            NaN        NaN        NaN        NaN   0.443310   0.594629
# 4            NaN        NaN        NaN   0.443310   0.594629   0.667937
# ...          ...        ...        ...        ...        ...        ...
# 17239   0.864354   0.812042   0.693552   0.561830   0.521225   0.506177
# 17240   0.812042   0.693552   0.561830   0.521225   0.506177   0.468468
# 17241   0.693552   0.561830   0.521225   0.506177   0.468468   0.480009
# 17242   0.561830   0.521225   0.506177   0.468468   0.480009   0.464170
# 17243   0.521225   0.506177   0.468468   0.480009   0.464170   0.577246
#
#        var1(t-1)   var1(t)
# 0            NaN  0.443310
# 1       0.443310  0.594629
# 2       0.594629  0.667937
# 3       0.667937  0.674017
# 4       0.674017  0.619492
# ...          ...       ...
# 17239   0.468468  0.480009
# 17240   0.480009  0.464170
# 17241   0.464170  0.577246
# 17242   0.577246  0.706595
# 17243   0.706595  0.751798
#
# [17244 rows x 8 columns]
# (17244, 8)

# %%
# 用2019-01-01到2019-12-09的数据来训练
values = reframed.values
train = values[:8208]
test = values[8208:]
# split into input and outputs
n_obs = n_hours * n_features
# 有4=(4*1)列数据，取前3=(3*1) 列作为X，倒数第1列=(第4列)作为Y
train_X, train_y = train[:, :n_obs], train[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]
print(train_X.shape, train_y.shape)
print(test_X.shape, test_y.shape)
# Out:
# (8208, 7) (8208,)
# (9029, 7) (9029,)

# %%
# 将数据转换为3D输入，timesteps=3，3条数据预测1条 [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (8208, 7, 1) (8208,) (9029, 7, 1) (9029,)

# %%
# 设计网络
model = Sequential()
model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(100, input_shape=(None, 100), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(100, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))
model.add(Activation("linear"))
# model.compile(loss='mae', optimizer='adam')
model.compile(loss='mse', optimizer='rmsprop')

# %%
# 设计网络
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False))
# model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mae', optimizer='adam', metrics=['mse', 'mae', 'mape', 'cosine']))

# %%
# 拟合网络
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 8208 samples, validate on 9029 samples
# Epoch 1/50
#  - 18s - loss: 0.0196 - val_loss: 0.0163
# Epoch 2/50
#  - 14s - loss: 0.0120 - val_loss: 0.0254
# Epoch 3/50
#  - 14s - loss: 0.0085 - val_loss: 0.0201
# Epoch 4/50
#  - 14s - loss: 0.0061 - val_loss: 0.0109
# Epoch 5/50
#  - 15s - loss: 0.0048 - val_loss: 0.0084
# Epoch 6/50
#  - 14s - loss: 0.0040 - val_loss: 0.0045
# Epoch 7/50
#  - 15s - loss: 0.0038 - val_loss: 0.0039
# Epoch 8/50
#  - 14s - loss: 0.0036 - val_loss: 0.0036
# Epoch 9/50
#  - 14s - loss: 0.0034 - val_loss: 0.0038
# Epoch 10/50
#  - 14s - loss: 0.0034 - val_loss: 0.0055
# Epoch 11/50
#  - 14s - loss: 0.0032 - val_loss: 0.0039
# Epoch 12/50
#  - 14s - loss: 0.0031 - val_loss: 0.0039
# Epoch 13/50
#  - 14s - loss: 0.0031 - val_loss: 0.0036
# Epoch 14/50
#  - 14s - loss: 0.0031 - val_loss: 0.0041
# Epoch 15/50
#  - 14s - loss: 0.0030 - val_loss: 0.0036
# Epoch 16/50
#  - 14s - loss: 0.0029 - val_loss: 0.0037
# Epoch 17/50
#  - 14s - loss: 0.0028 - val_loss: 0.0048
# Epoch 18/50
#  - 14s - loss: 0.0028 - val_loss: 0.0040
# Epoch 19/50
#  - 14s - loss: 0.0028 - val_loss: 0.0040
# Epoch 20/50
#  - 14s - loss: 0.0027 - val_loss: 0.0060
# Epoch 21/50
#  - 14s - loss: 0.0028 - val_loss: 0.0050
# Epoch 22/50
#  - 14s - loss: 0.0027 - val_loss: 0.0055
# Epoch 23/50
#  - 14s - loss: 0.0027 - val_loss: 0.0055
# Epoch 24/50
#  - 14s - loss: 0.0027 - val_loss: 0.0048
# Epoch 25/50
#  - 14s - loss: 0.0026 - val_loss: 0.0049
# Epoch 26/50
#  - 14s - loss: 0.0026 - val_loss: 0.0045
# Epoch 27/50
#  - 14s - loss: 0.0026 - val_loss: 0.0049
# Epoch 28/50
#  - 14s - loss: 0.0026 - val_loss: 0.0046
# Epoch 29/50
#  - 14s - loss: 0.0026 - val_loss: 0.0049
# Epoch 30/50
#  - 14s - loss: 0.0026 - val_loss: 0.0045
# Epoch 31/50
#  - 14s - loss: 0.0025 - val_loss: 0.0052
# Epoch 32/50
#  - 14s - loss: 0.0026 - val_loss: 0.0050
# Epoch 33/50
#  - 14s - loss: 0.0025 - val_loss: 0.0052
# Epoch 34/50
#  - 14s - loss: 0.0025 - val_loss: 0.0048
# Epoch 35/50
#  - 14s - loss: 0.0024 - val_loss: 0.0047
# Epoch 36/50
#  - 14s - loss: 0.0024 - val_loss: 0.0046
# Epoch 37/50
#  - 14s - loss: 0.0024 - val_loss: 0.0053
# Epoch 38/50
#  - 14s - loss: 0.0024 - val_loss: 0.0055
# Epoch 39/50
#  - 14s - loss: 0.0023 - val_loss: 0.0050
# Epoch 40/50
#  - 14s - loss: 0.0023 - val_loss: 0.0047
# Epoch 41/50
#  - 14s - loss: 0.0023 - val_loss: 0.0048
# Epoch 42/50
#  - 14s - loss: 0.0023 - val_loss: 0.0044
# Epoch 43/50
#  - 14s - loss: 0.0023 - val_loss: 0.0046
# Epoch 44/50
#  - 14s - loss: 0.0022 - val_loss: 0.0049
# Epoch 45/50
#  - 14s - loss: 0.0022 - val_loss: 0.0049
# Epoch 46/50
#  - 14s - loss: 0.0022 - val_loss: 0.0046
# Epoch 47/50
#  - 14s - loss: 0.0022 - val_loss: 0.0042
# Epoch 48/50
#  - 14s - loss: 0.0022 - val_loss: 0.0041
# Epoch 49/50
#  - 15s - loss: 0.0021 - val_loss: 0.0037
# Epoch 50/50
#  - 18s - loss: 0.0021 - val_loss: 0.0044

# %%
score = model.evaluate(test_X, test_y)
print(score)
# Out:
# 9029/9029 [==============================] - 1s 157us/step
# 0.0396404548446355

# %%
plt.plot(history.history['mse'])
plt.plot(history.history['mae'])
plt.plot(history.history['mape'])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-1679b5c7a3fc> in <module>
# ----> 1 plt.plot(history.history['mse'])
#       2 plt.plot(history.history['mae'])
#       3 plt.plot(history.history['mape'])
#       4 plt.legend()
#       5 plt.show()
#
# KeyError: 'mse'

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# 执行预测
yhat = model.predict(test_X)
# 将数据格式化成 n行 * 3列
test_X = test_X.reshape((test_X.shape[0], n_hours*n_features))

# %%
# 将预测列据和后7列数据拼接，因后续逆缩放时，数据形状要符合 n行*8列 的要求
inv_yhat = concatenate((yhat, test_X[:, -1:]), axis=1)
# 对拼接好的数据进行逆缩放
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
# inv_yhat = inverse_difference(raw_value[8212:], inv_yhat)

# %%
test_y = test_y.reshape((len(test_y), 1))
# 将真实列据和后7列数据拼接，因后续逆缩放时，数据形状要符合 n行*8列 的要求
inv_y = concatenate((test_y, test_X[:, -1:]), axis=1)
# 对拼接好的数据进行逆缩放
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]

# %%
# 画预测图
plt.figure(figsize=(15,15))
plt.title('2020-2021 Wuxi Gas True Usage vs Prediction')
x = series['time'][8215:]
y = series['amount'][8215:]
plt.plot(x, y, color='b', label='True Data')
plt.plot(x, inv_yhat, color='r', label='Predicted Data')
plt.xlabel('Date')
plt.ylabel('Gas Usage')
plt.tight_layout()
plt.legend()
plt.show()

# %%
# 转换成监督数据，四列数据，3->1，三组预测一组
def new_series_to_supervised(data, n_in=1, n_out=1):
    n_vars = 1
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    # 将3组输入数据依次向下移动3，2，1行，将数据加入cols列表（技巧：(n_in, 0, -1)中的-1指倒序循环，步长为1）
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    # 将一组输出数据加入cols列表（技巧：其中i=0）
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # cols列表(list)中现在有四块经过下移后的数据(即：df(-3),df(-2),df(-1),df)，将四块数据按列 并排合并
    agg = concat(cols, axis=1)
    # 给合并后的数据添加列名
    agg.columns = names
    return agg

# 使用前三天数据预测未来一天的数据
def prediction(original):
    history = original[-3:]
    history = np.append(history, [0])
    # time = series['time'][8211:8216]
    reframed = new_series_to_supervised(history, n_hours, 1)
    reframed.dropna(inplace=True)
    test_X = reframed.values[:, :-1]
    # 标准化/放缩 特征值在（0,1）之间
    scaler = MinMaxScaler(feature_range=(0, 1))
    test_X = scaler.fit_transform(test_X.reshape(-1, 1))
    test_X = test_X.reshape((1, n_hours, n_features))
    yhat = model.predict(test_X)
    # 将数据格式化成 1行*3列
    test_X = test_X.reshape((test_X.shape[0], n_hours * n_features))
    # 对拼接好的数据进行逆缩放
    inv_yhat = scaler.inverse_transform(yhat)
    inv_yhat = inv_yhat[:, 0]
    return inv_yhat[0]


# 预测一个月的数据
original = series['amount'][8211:8214].values.astype('float32')
nhours = 24
predicted_dates = series['time'][8211:8214 + nhours]
for i in range(nhours):
    result = prediction(original)
    original = np.append(original, result)

print(original)
# Out:
# [114465.    100053.    100839.    100322.484 100032.06  100001.
#   99988.055  99986.49   99985.914  99985.84   99985.82   99985.81
#   99985.81   99985.81   99985.836  99985.84   99985.84   99985.84
#   99985.87   99985.875  99985.875  99985.875  99985.9    99985.91
#   99985.91   99985.91   99985.93 ]

# %%
# 画预测图
plt.figure(figsize=(15,15))
plt.title('2020-2021 Wuxi Gas True Usage vs Prediction')
x = predicted_dates
y = series['amount'][8211:8214 + nhours]
yhat = original
plt.plot(x, y, color='b', label='True Data')
plt.plot(x, yhat, color='r', label='Predicted Data')
plt.xlabel('Date')
plt.ylabel('Gas Usage')
plt.tight_layout()
plt.legend()
plt.show()
